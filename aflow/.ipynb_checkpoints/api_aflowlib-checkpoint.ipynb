# %%
import json # preamble
from urllib.request import urlopen # preamble
from scipy import *

# %%
SERVER='http://aflowlib.duke.edu' # server name
PROJECT='AFLOWDATA/LIB3_RAW/' # project name
URL=SERVER+'/'+PROJECT # project-layer
#URL=SERVER+'/'+PROJECT+'AlCu_pvMn_pv/' # set-layer
#URL=SERVER+'/'+PROJECT+'AlCu_pvMn_pv/T0001.A2BC/' # calculation-layer
print(URL)
# Out:
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/

# %%
entry=json.loads(urlopen(URL+'?format=json').read().decode('utf-8')) # load
print(len(entry))
# Out:
# 6

# %%
len(entry['aflowlib_entries'])
# Out:
# 30009

# %%
type(entry)
print([key for key in entry])
# Out:
# ['aflowlib_entries', 'keywords', 'aapi', 'auid', 'aurl', 'aflowlib_entries_number']

# %%
data_list=[]
for comp in entry['aflowlib_entries'][1:10]:
    address=URL+comp+'?format=json'
    print(address)
    ent=json.loads(urlopen(address).read().decode('utf-8')) # load
    data_list.append(ent)
# Out:
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlAs?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlAu?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlB_h?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlBa_sv?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlBe_sv?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlBi_d?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlBr?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlCa_sv?format=json
# http://aflowlib.duke.edu/AFLOWDATA/LIB3_RAW/AgAlCd?format=json

# %%
SERVER='http://aflowlib.duke.edu' # server name
PROJECT='AFLOWDATA/LIB2_RAW/' # project name
URL=SERVER+'/'+PROJECT # project-layer
#URL=SERVER+'/'+PROJECT+'AlCu_pvMn_pv/' # set-layer
#URL=SERVER+'/'+PROJECT+'AlCu_pvMn_pv/T0001.A2BC/' # calculation-layer
print(URL)
# Out:
# http://aflowlib.duke.edu/AFLOWDATA/LIB2_RAW/

# %%
entry2=json.loads(urlopen(URL+'?format=json').read().decode('utf-8')) # load
print(len(entry))
# Out:
# 6

# %%
entry2
# Out:
# {'aapi': '1.0',
#  'aflowlib_entries': ['AgAl',
#   'AgAs',
#   'AgAu',
#   'AgB_h',
#   'AgBa_sv',
#   'AgBe_sv',
#   'AgBi_d',
#   'AgBr',
#   'AgCa_sv',
#   'AgCd',
#   'AgCl',
#   'AgCo',
#   'AgCr_pv',
#   'AgCu_pv',
#   'AgFe_pv',
#   'AgGa_h',
#   'AgGe_h',
#   'AgHf_pv',
#   'AgHg',
#   'AgIn_d',
#   'AgIr',
#   'AgK_sv',
#   'AgLa',
#   'AgLi_sv',
#   'AgMg_pv',
#   'AgMn_pv',
#   'AgMo_pv',
#   'AgNa_sv',
#   'AgNb_sv',
#   'AgNi_pv',
#   'AgOs_pv',
#   'AgP',
#   'AgPb_d',
#   'AgPd_pv',
#   'AgPt',
#   'AgRe_pv',
#   'AgRh_pv',
#   'AgRu_pv',
#   'AgSb',
#   'AgSc_sv',
#   'AgSe',
#   'AgSi',
#   'AgSn',
#   'AgSr_sv',
#   'AgTa_pv',
#   'AgTc_pv',
#   'AgTe',
#   'AgTi_sv',
#   'AgTl_d',
#   'AgV_sv',
#   'AgW_pv',
#   'AgY_sv',
#   'AgZn',
#   'AgZr_sv',
#   'AlAs',
#   'AlAu',
#   'AlB_h',
#   'AlBa_sv',
#   'AlBe_sv',
#   'AlBi_d',
#   'AlBr',
#   'AlCa_sv',
#   'AlCd',
#   'AlCl',
#   'AlCo',
#   'AlCr_pv',
#   'AlCu_pv',
#   'AlFe_pv',
#   'AlGa_h',
#   'AlGe_h',
#   'AlHf_pv',
#   'AlHg',
#   'AlIn_d',
#   'AlIr',
#   'AlK_sv',
#   'AlLa',
#   'AlLi_sv',
#   'AlMg_pv',
#   'AlMn_pv',
#   'AlMo_pv',
#   'AlNa_sv',
#   'AlNb_sv',
#   'AlNi_pv',
#   'AlOs_pv',
#   'AlP',
#   'AlPb_d',
#   'AlPd_pv',
#   'AlPt',
#   'AlRe_pv',
#   'AlRh_pv',
#   'AlRu_pv',
#   'AlSb',
#   'AlSc_sv',
#   'AlSe',
#   'AlSi',
#   'AlSn',
#   'AlSr_sv',
#   'AlTa_pv',
#   'AlTc_pv',
#   'AlTe',
#   'AlTi_sv',
#   'AlTl_d',
#   'AlV_sv',
#   'AlW_pv',
#   'AlY_sv',
#   'AlZn',
#   'AlZr_sv',
#   'AsAu',
#   'AsB_h',
#   'AsBa_sv',
#   'AsBe_sv',
#   'AsBi_d',
#   'AsBr',
#   'AsCa_sv',
#   'AsCd',
#   'AsCl',
#   'AsCo',
#   'AsCr_pv',
#   'AsCu_pv',
#   'AsFe_pv',
#   'AsGa_h',
#   'AsGe_h',
#   'AsHf_pv',
#   'AsHg',
#   'AsIn_d',
#   'AsIr',
#   'AsK_sv',
#   'AsLa',
#   'AsLi_sv',
#   'AsMg_pv',
#   'AsMn_pv',
#   'AsMo_pv',
#   'AsNa_sv',
#   'AsNb_sv',
#   'AsNi_pv',
#   'AsOs_pv',
#   'AsP',
#   'AsPb_d',
#   'AsPd_pv',
#   'AsPt',
#   'AsRe_pv',
#   'AsRh_pv',
#   'AsRu_pv',
#   'AsSb',
#   'AsSc_sv',
#   'AsSe',
#   'AsSi',
#   'AsSn',
#   'AsSr_sv',
#   'AsTa_pv',
#   'AsTc_pv',
#   'AsTe',
#   'AsTi_sv',
#   'AsTl_d',
#   'AsV_sv',
#   'AsW_pv',
#   'AsY_sv',
#   'AsZn',
#   'AsZr_sv',
#   'AuB_h',
#   'AuBa_sv',
#   'AuBe_sv',
#   'AuBi_d',
#   'AuBr',
#   'AuCa_sv',
#   'AuCd',
#   'AuCl',
#   'AuCo',
#   'AuCr_pv',
#   'AuCu_pv',
#   'AuFe_pv',
#   'AuGa_h',
#   'AuGe_h',
#   'AuHf_pv',
#   'AuHg',
#   'AuIn_d',
#   'AuIr',
#   'AuK_sv',
#   'AuLa',
#   'AuLi_sv',
#   'AuMg_pv',
#   'AuMn_pv',
#   'AuMo_pv',
#   'AuNa_sv',
#   'AuNb_sv',
#   'AuNi_pv',
#   'AuOs_pv',
#   'AuP',
#   'AuPb_d',
#   'AuPd_pv',
#   'AuPt',
#   'AuRe_pv',
#   'AuRh_pv',
#   'AuRu_pv',
#   'AuSb',
#   'AuSc_sv',
#   'AuSe',
#   'AuSi',
#   'AuSn',
#   'AuSr_sv',
#   'AuTa_pv',
#   'AuTc_pv',
#   'AuTe',
#   'AuTi_sv',
#   'AuTl_d',
#   'AuV_sv',
#   'AuW_pv',
#   'AuY_sv',
#   'AuZn',
#   'AuZr_sv',
#   'B_hBa_sv',
#   'B_hBe_sv',
#   'B_hBi_d',
#   'B_hBr',
#   'B_hCa_sv',
#   'B_hCd',
#   'B_hCl',
#   'B_hCo',
#   'B_hCr_pv',
#   'B_hCu_pv',
#   'B_hFe_pv',
#   'B_hGa_h',
#   'B_hGe_h',
#   'B_hHf_pv',
#   'B_hHg',
#   'B_hIn_d',
#   'B_hIr',
#   'B_hK_sv',
#   'B_hLa',
#   'B_hLi_sv',
#   'B_hMg_pv',
#   'B_hMn_pv',
#   'B_hMo_pv',
#   'B_hNa_sv',
#   'B_hNb_sv',
#   'B_hNi_pv',
#   'B_hOs_pv',
#   'B_hP',
#   'B_hPb_d',
#   'B_hPd_pv',
#   'B_hPt',
#   'B_hRe_pv',
#   'B_hRh_pv',
#   'B_hRu_pv',
#   'B_hSb',
#   'B_hSc_sv',
#   'B_hSe',
#   'B_hSi',
#   'B_hSm_3',
#   'B_hSn',
#   'B_hSr_sv',
#   'B_hTa_pv',
#   'B_hTc_pv',
#   'B_hTe',
#   'B_hTi_sv',
#   'B_hTl_d',
#   'B_hV_sv',
#   'B_hW_pv',
#   'B_hY_sv',
#   'B_hZn',
#   'B_hZr_sv',
#   'B_sHf_pv',
#   'Ba_svBe_sv',
#   'Ba_svBi_d',
#   'Ba_svBr',
#   'Ba_svCa_sv',
#   'Ba_svCd',
#   'Ba_svCl',
#   'Ba_svCo',
#   'Ba_svCr_pv',
#   'Ba_svCu_pv',
#   'Ba_svFe_pv',
#   'Ba_svGa_h',
#   'Ba_svGe_h',
#   'Ba_svHf_pv',
#   'Ba_svHg',
#   'Ba_svIn_d',
#   'Ba_svIr',
#   'Ba_svK_sv',
#   'Ba_svLa',
#   'Ba_svLi_sv',
#   'Ba_svMg_pv',
#   'Ba_svMn_pv',
#   'Ba_svMo_pv',
#   'Ba_svNa_sv',
#   'Ba_svNb_sv',
#   'Ba_svNi_pv',
#   'Ba_svOs_pv',
#   'Ba_svP',
#   'Ba_svPb_d',
#   'Ba_svPd_pv',
#   'Ba_svPt',
#   'Ba_svRe_pv',
#   'Ba_svRh_pv',
#   'Ba_svRu_pv',
#   'Ba_svSb',
#   'Ba_svSc_sv',
#   'Ba_svSe',
#   'Ba_svSi',
#   'Ba_svSn',
#   'Ba_svSr_sv',
#   'Ba_svTa_pv',
#   'Ba_svTc_pv',
#   'Ba_svTe',
#   'Ba_svTi_sv',
#   'Ba_svTl_d',
#   'Ba_svV_sv',
#   'Ba_svW_pv',
#   'Ba_svY_sv',
#   'Ba_svZn',
#   'Ba_svZr_sv',
#   'BeHf_pv',
#   'Be_svBi_d',
#   'Be_svBr',
#   'Be_svCa_sv',
#   'Be_svCd',
#   'Be_svCl',
#   'Be_svCo',
#   'Be_svCr_pv',
#   'Be_svCu_pv',
#   'Be_svFe_pv',
#   'Be_svGa_h',
#   'Be_svGe_h',
#   'Be_svHg',
#   'Be_svIn_d',
#   'Be_svIr',
#   'Be_svK_sv',
#   'Be_svLa',
#   'Be_svLi_sv',
#   'Be_svMg_pv',
#   'Be_svMn_pv',
#   'Be_svMo_pv',
#   'Be_svNa_sv',
#   'Be_svNb_sv',
#   'Be_svNi_pv',
#   'Be_svOs_pv',
#   'Be_svP',
#   'Be_svPb_d',
#   'Be_svPd_pv',
#   'Be_svPt',
#   'Be_svRe_pv',
#   'Be_svRh_pv',
#   'Be_svRu_pv',
#   'Be_svSb',
#   'Be_svSc_sv',
#   'Be_svSe',
#   'Be_svSi',
#   'Be_svSn',
#   'Be_svSr_sv',
#   'Be_svTa_pv',
#   'Be_svTc_pv',
#   'Be_svTe',
#   'Be_svTi_sv',
#   'Be_svTl_d',
#   'Be_svV_sv',
#   'Be_svW_pv',
#   'Be_svY_sv',
#   'Be_svZn',
#   'Be_svZr_sv',
#   'Bi_dBr',
#   'Bi_dCa_sv',
#   'Bi_dCd',
#   'Bi_dCl',
#   'Bi_dCo',
#   'Bi_dCr_pv',
#   'Bi_dCu_pv',
#   'Bi_dFe_pv',
#   'Bi_dGa_h',
#   'Bi_dGe_h',
#   'Bi_dHf_pv',
#   'Bi_dHg',
#   'Bi_dIn_d',
#   'Bi_dIr',
#   'Bi_dK_sv',
#   'Bi_dLa',
#   'Bi_dLi_sv',
#   'Bi_dMg_pv',
#   'Bi_dMn_pv',
#   'Bi_dMo_pv',
#   'Bi_dNa_sv',
#   'Bi_dNb_sv',
#   'Bi_dNi_pv',
#   'Bi_dOs_pv',
#   'Bi_dP',
#   'Bi_dPb_d',
#   'Bi_dPd_pv',
#   'Bi_dPt',
#   'Bi_dRe_pv',
#   'Bi_dRh_pv',
#   'Bi_dRu_pv',
#   'Bi_dSb',
#   'Bi_dSc_sv',
#   'Bi_dSe',
#   'Bi_dSi',
#   'Bi_dSn',
#   'Bi_dSr_sv',
#   'Bi_dTa_pv',
#   'Bi_dTc_pv',
#   'Bi_dTe',
#   'Bi_dTi_sv',
#   'Bi_dTl_d',
#   'Bi_dV_sv',
#   'Bi_dW_pv',
#   'Bi_dY_sv',
#   'Bi_dZn',
#   'Bi_dZr_sv',
#   'BrCa_sv',
#   'BrCd',
#   'BrCl',
#   'BrCo',
#   'BrCr_pv',
#   'BrCu_pv',
#   'BrFe_pv',
#   'BrGa_h',
#   'BrGe_h',
#   'BrHf_pv',
#   'BrHg',
#   'BrIn_d',
#   'BrIr',
#   'BrK_sv',
#   'BrLa',
#   'BrLi_sv',
#   'BrMg_pv',
#   'BrMn_pv',
#   'BrMo_pv',
#   'BrNa_sv',
#   'BrNb_sv',
#   'BrNi_pv',
#   'BrOs_pv',
#   'BrP',
#   'BrPb_d',
#   'BrPd_pv',
#   'BrPt',
#   'BrRe_pv',
#   'BrRh_pv',
#   'BrRu_pv',
#   'BrSb',
#   'BrSc_sv',
#   'BrSe',
#   'BrSi',
#   'BrSn',
#   'BrSr_sv',
#   'BrTa_pv',
#   'BrTc_pv',
#   'BrTe',
#   'BrTi_sv',
#   'BrTl_d',
#   'BrV_sv',
#   'BrW_pv',
#   'BrY_sv',
#   'BrZn',
#   'BrZr_sv',
#   'CHf_pv',
#   'CNb_sv',
#   'CNi_pv',
#   'CTa_pv',
#   'CZr_sv',
#   'Ca_svCd',
#   'Ca_svCl',
#   'Ca_svCo',
#   'Ca_svCr_pv',
#   'Ca_svCu_pv',
#   'Ca_svFe_pv',
#   'Ca_svGa_h',
#   'Ca_svGe_h',
#   'Ca_svHf_pv',
#   'Ca_svHg',
#   'Ca_svIn_d',
#   'Ca_svIr',
#   'Ca_svK_sv',
#   'Ca_svLa',
#   'Ca_svLi_sv',
#   'Ca_svMg_pv',
#   'Ca_svMn_pv',
#   'Ca_svMo_pv',
#   'Ca_svNa_sv',
#   'Ca_svNb_sv',
#   'Ca_svNi_pv',
#   'Ca_svOs_pv',
#   'Ca_svP',
#   'Ca_svPb_d',
#   'Ca_svPd_pv',
#   'Ca_svPt',
#   'Ca_svRe_pv',
#   'Ca_svRh_pv',
#   'Ca_svRu_pv',
#   'Ca_svSb',
#   'Ca_svSc_sv',
#   'Ca_svSe',
#   'Ca_svSi',
#   'Ca_svSn',
#   'Ca_svSr_sv',
#   'Ca_svTa_pv',
#   'Ca_svTc_pv',
#   'Ca_svTe',
#   'Ca_svTi_sv',
#   'Ca_svTl_d',
#   'Ca_svV_sv',
#   'Ca_svW_pv',
#   'Ca_svY_sv',
#   'Ca_svZn',
#   'Ca_svZr_sv',
#   'CdCl',
#   'CdCo',
#   'CdCr_pv',
#   'CdCu_pv',
#   'CdFe_pv',
#   'CdGa_h',
#   'CdGe_h',
#   'CdHf_pv',
#   'CdHg',
#   'CdIn_d',
#   'CdIr',
#   'CdK_sv',
#   'CdLa',
#   'CdLi_sv',
#   'CdMg_pv',
#   'CdMn_pv',
#   'CdMo_pv',
#   'CdNa_sv',
#   'CdNb_sv',
#   'CdNi_pv',
#   'CdOs_pv',
#   'CdP',
#   'CdPb_d',
#   'CdPd_pv',
#   'CdPt',
#   'CdRe_pv',
#   'CdRh_pv',
#   'CdRu_pv',
#   'CdSb',
#   'CdSc_sv',
#   'CdSe',
#   'CdSi',
#   'CdSn',
#   'CdSr_sv',
#   'CdTa_pv',
#   'CdTc_pv',
#   'CdTe',
#   'CdTi_sv',
#   'CdTl_d',
#   'CdV_sv',
#   'CdW_pv',
#   'CdY_sv',
#   'CdZn',
#   'CdZr_sv',
#   'CeMg_pv',
#   'ClCo',
#   'ClCr_pv',
#   'ClCu_pv',
#   'ClFe_pv',
#   'ClGa_h',
#   'ClGe_h',
#   'ClHf_pv',
#   'ClHg',
#   'ClIn_d',
#   'ClIr',
#   'ClK_sv',
#   'ClLa',
#   'ClLi_sv',
#   'ClMg_pv',
#   'ClMn_pv',
#   'ClMo_pv',
#   'ClNa_sv',
#   'ClNb_sv',
#   'ClNi_pv',
#   'ClOs_pv',
#   'ClP',
#   'ClPb_d',
#   'ClPd_pv',
#   'ClPt',
#   'ClRe_pv',
#   'ClRh_pv',
#   'ClRu_pv',
#   'ClSb',
#   'ClSc_sv',
#   'ClSe',
#   'ClSi',
#   'ClSn',
#   'ClSr_sv',
#   'ClTa_pv',
#   'ClTc_pv',
#   'ClTe',
#   'ClTi_sv',
#   'ClTl_d',
#   'ClV_sv',
#   'ClW_pv',
#   'ClY_sv',
#   'ClZn',
#   'ClZr_sv',
#   'CoCr_pv',
#   'CoCu_pv',
#   'CoFe_pv',
#   'CoGa_h',
#   'CoGe_h',
#   'CoHf_pv',
#   'CoHg',
#   'CoIn_d',
#   'CoIr',
#   'CoK_sv',
#   'CoLa',
#   'CoLi_sv',
#   'CoMg_pv',
#   'CoMn_pv',
#   'CoMo_pv',
#   'CoNa_sv',
#   'CoNb_sv',
#   'CoNi_pv',
#   'CoOs_pv',
#   'CoP',
#   'CoPb_d',
#   'CoPd_pv',
#   'CoPt',
#   'CoRe_pv',
#   'CoRh_pv',
#   'CoRu_pv',
#   'CoSb',
#   'CoSc_sv',
#   'CoSe',
#   'CoSi',
#   'CoSn',
#   'CoSr_sv',
#   'CoTa_pv',
#   'CoTc_pv',
#   'CoTe',
#   'CoTi_sv',
#   'CoTl_d',
#   'CoV_sv',
#   'CoW_pv',
#   'CoY_sv',
#   'CoZn',
#   'CoZr_sv',
#   'Cr_pvCu_pv',
#   'Cr_pvFe_pv',
#   'Cr_pvGa_h',
#   'Cr_pvGe_h',
#   'Cr_pvHf_pv',
#   'Cr_pvHg',
#   'Cr_pvIn_d',
#   'Cr_pvIr',
#   'Cr_pvK_sv',
#   'Cr_pvLa',
#   'Cr_pvLi_sv',
#   'Cr_pvMg_pv',
#   'Cr_pvMn_pv',
#   'Cr_pvMo_pv',
#   'Cr_pvNa_sv',
#   'Cr_pvNb_sv',
#   'Cr_pvNi_pv',
#   'Cr_pvOs_pv',
#   'Cr_pvP',
#   'Cr_pvPb_d',
#   'Cr_pvPd_pv',
#   'Cr_pvPt',
#   'Cr_pvRe_pv',
#   'Cr_pvRh_pv',
#   'Cr_pvRu_pv',
#   'Cr_pvSb',
#   'Cr_pvSc_sv',
#   'Cr_pvSe',
#   'Cr_pvSi',
#   'Cr_pvSn',
#   'Cr_pvSr_sv',
#   'Cr_pvTa_pv',
#   'Cr_pvTc_pv',
#   'Cr_pvTe',
#   'Cr_pvTi_sv',
#   'Cr_pvTl_d',
#   'Cr_pvV_sv',
#   'Cr_pvW_pv',
#   'Cr_pvY_sv',
#   'Cr_pvZn',
#   'Cr_pvZr_sv',
#   'Cs_svPd_pv',
#   'Cu_pvFe_pv',
#   'Cu_pvGa_h',
#   'Cu_pvGe_h',
#   'Cu_pvHf_pv',
#   'Cu_pvHg',
#   'Cu_pvIn_d',
#   'Cu_pvIr',
#   'Cu_pvK_sv',
#   'Cu_pvLa',
#   'Cu_pvLi_sv',
#   'Cu_pvMg_pv',
#   'Cu_pvMn_pv',
#   'Cu_pvMo_pv',
#   'Cu_pvNa_sv',
#   'Cu_pvNb_sv',
#   'Cu_pvNi_pv',
#   'Cu_pvOs_pv',
#   'Cu_pvP',
#   'Cu_pvPb_d',
#   'Cu_pvPd_pv',
#   'Cu_pvPt',
#   'Cu_pvRe_pv',
#   'Cu_pvRh_pv',
#   'Cu_pvRu_pv',
#   'Cu_pvSb',
#   'Cu_pvSc_sv',
#   'Cu_pvSe',
#   'Cu_pvSi',
#   'Cu_pvSn',
#   'Cu_pvSr_sv',
#   'Cu_pvTa_pv',
#   'Cu_pvTc_pv',
#   'Cu_pvTe',
#   'Cu_pvTi_sv',
#   'Cu_pvTl_d',
#   'Cu_pvV_sv',
#   'Cu_pvW_pv',
#   'Cu_pvY_sv',
#   'Cu_pvZn',
#   'Cu_pvZr_sv',
#   'Fe_pvGa_h',
#   'Fe_pvGe_h',
#   'Fe_pvHf_pv',
#   'Fe_pvHg',
#   'Fe_pvIn_d',
#   'Fe_pvIr',
#   'Fe_pvK_sv',
#   'Fe_pvLa',
#   'Fe_pvLi_sv',
#   'Fe_pvMg_pv',
#   'Fe_pvMn_pv',
#   'Fe_pvMo_pv',
#   'Fe_pvNa_sv',
#   'Fe_pvNb_sv',
#   'Fe_pvNi_pv',
#   'Fe_pvOs_pv',
#   'Fe_pvP',
#   'Fe_pvPb_d',
#   'Fe_pvPd_pv',
#   'Fe_pvPt',
#   'Fe_pvRe_pv',
#   'Fe_pvRh_pv',
#   'Fe_pvRu_pv',
#   'Fe_pvSb',
#   'Fe_pvSc_sv',
#   'Fe_pvSe',
#   'Fe_pvSi',
#   'Fe_pvSn',
#   'Fe_pvSr_sv',
#   'Fe_pvTa_pv',
#   'Fe_pvTc_pv',
#   'Fe_pvTe',
#   'Fe_pvTi_sv',
#   'Fe_pvTl_d',
#   'Fe_pvV_sv',
#   'Fe_pvW_pv',
#   'Fe_pvY_sv',
#   'Fe_pvZn',
#   'Fe_pvZr_sv',
#   'GaMg_pv',
#   'Ga_hGe_h',
#   'Ga_hHf_pv',
#   'Ga_hHg',
#   'Ga_hIn_d',
#   'Ga_hIr',
#   'Ga_hK_sv',
#   'Ga_hLa',
#   'Ga_hLi_sv',
#   'Ga_hMg_pv',
#   'Ga_hMn_pv',
#   'Ga_hMo_pv',
#   'Ga_hNa_sv',
#   'Ga_hNb_sv',
#   'Ga_hNi_pv',
#   'Ga_hOs_pv',
#   'Ga_hP',
#   'Ga_hPb_d',
#   'Ga_hPd_pv',
#   'Ga_hPt',
#   'Ga_hRe_pv',
#   'Ga_hRh_pv',
#   'Ga_hRu_pv',
#   'Ga_hSb',
#   'Ga_hSc_sv',
#   'Ga_hSe',
#   'Ga_hSi',
#   'Ga_hSn',
#   'Ga_hSr_sv',
#   'Ga_hTa_pv',
#   'Ga_hTc_pv',
#   'Ga_hTe',
#   'Ga_hTi_sv',
#   'Ga_hTl_d',
#   'Ga_hV_sv',
#   'Ga_hW_pv',
#   'Ga_hY_sv',
#   'Ga_hZn',
#   'Ga_hZr_sv',
#   'GdMg_pv',
#   'GeMg_pv',
#   'Ge_hHf_pv',
#   'Ge_hHg',
#   'Ge_hIn_d',
#   'Ge_hIr',
#   'Ge_hK_sv',
#   'Ge_hLa',
#   'Ge_hLi_sv',
#   'Ge_hMg_pv',
#   'Ge_hMn_pv',
#   'Ge_hMo_pv',
#   'Ge_hNa_sv',
#   'Ge_hNb_sv',
#   'Ge_hNi_pv',
#   'Ge_hOs_pv',
#   'Ge_hP',
#   'Ge_hPb_d',
#   'Ge_hPd_pv',
#   'Ge_hPt',
#   'Ge_hRe_pv',
#   'Ge_hRh_pv',
#   'Ge_hRu_pv',
#   'Ge_hSb',
#   'Ge_hSc_sv',
#   'Ge_hSe',
#   'Ge_hSi',
#   'Ge_hSn',
#   'Ge_hSr_sv',
#   'Ge_hTa_pv',
#   'Ge_hTc_pv',
#   'Ge_hTe',
#   'Ge_hTi_sv',
#   'Ge_hTl_d',
#   'Ge_hV_sv',
#   'Ge_hW_pv',
#   'Ge_hY_sv',
#   'Ge_hZn',
#   'Ge_hZr_sv',
#   'Hf_pvHg',
#   'Hf_pvIn_d',
#   'Hf_pvIr',
#   'Hf_pvK_pv',
#   'Hf_pvLa',
#   'Hf_pvLi_sv',
#   'Hf_pvMg_pv',
#   'Hf_pvMn_pv',
#   'Hf_pvMo_pv',
#   'Hf_pvNa_pv',
#   'Hf_pvNa_sv',
#   'Hf_pvNb_sv',
#   'Hf_pvNi_pv',
#   'Hf_pvOs_pv',
#   'Hf_pvP',
#   'Hf_pvPb_d',
#   'Hf_pvPd_pv',
#   'Hf_pvPt',
#   'Hf_pvRe_pv',
#   'Hf_pvRh_pv',
#   'Hf_pvRu_pv',
#   'Hf_pvSb',
#   'Hf_pvSc_sv',
#   'Hf_pvSe',
#   'Hf_pvSi',
#   'Hf_pvSn',
#   'Hf_pvSn_d',
#   'Hf_pvSr_sv',
#   'Hf_pvTa_pv',
#   'Hf_pvTc_pv',
#   'Hf_pvTe',
#   'Hf_pvTi_sv',
#   'Hf_pvTl_d',
#   'Hf_pvV_sv',
#   'Hf_pvW_pv',
#   'Hf_pvY_sv',
#   'Hf_pvZn',
#   'Hf_pvZr_sv',
#   'HgIn_d',
#   'HgIr',
#   'HgK_sv',
#   'HgLa',
#   'HgLi_sv',
#   'HgMg_pv',
#   'HgMn_pv',
#   'HgMo_pv',
#   'HgNa_sv',
#   'HgNb_sv',
#   'HgNi_pv',
#   'HgOs_pv',
#   'HgP',
#   'HgPb_d',
#   'HgPd_pv',
#   'HgPt',
#   'HgRe_pv',
#   'HgRh_pv',
#   'HgRu_pv',
#   'HgSb',
#   'HgSc_sv',
#   'HgSe',
#   'HgSi',
#   'HgSn',
#   'HgSr_sv',
#   'HgTa_pv',
#   'HgTc_pv',
#   'HgTe',
#   'HgTi_sv',
#   'HgTl_d',
#   'HgV_sv',
#   'HgW_pv',
#   'HgY_sv',
#   'HgZn',
#   'HgZr_sv',
#   'In_dIr',
#   'In_dK_sv',
#   'In_dLa',
#   'In_dLi_sv',
#   'In_dMg_pv',
#   'In_dMn_pv',
#   'In_dMo_pv',
#   'In_dNa_sv',
#   'In_dNb_sv',
#   'In_dNi_pv',
#   'In_dOs_pv',
#   'In_dP',
#   'In_dPb_d',
#   'In_dPd_pv',
#   'In_dPt',
#   'In_dRe_pv',
#   'In_dRh_pv',
#   'In_dRu_pv',
#   'In_dSb',
#   'In_dSc_sv',
#   'In_dSe',
#   'In_dSi',
#   'In_dSn',
#   'In_dSr_sv',
#   'In_dTa_pv',
#   'In_dTc_pv',
#   'In_dTe',
#   'In_dTi_sv',
#   'In_dTl_d',
#   'In_dV_sv',
#   'In_dW_pv',
#   'In_dY_sv',
#   'In_dZn',
#   'In_dZr_sv',
#   'IrK_sv',
#   'IrLa',
#   'IrLi_sv',
#   'IrMg_pv',
#   'IrMn_pv',
#   'IrMo_pv',
#   'IrNa_sv',
#   'IrNb_sv',
#   'IrNi_pv',
#   'IrOs_pv',
#   'IrP',
#   'IrPb_d',
#   'IrPd_pv',
#   'IrPt',
#   'IrRe_pv',
#   'IrRh_pv',
#   'IrRu_pv',
#   'IrSb',
#   'IrSc_sv',
#   'IrSe',
#   'IrSi',
#   'IrSn',
#   'IrSr_sv',
#   'IrTa_pv',
#   'IrTc_pv',
#   'IrTe',
#   'IrTi_sv',
#   'IrTl_d',
#   'IrV_sv',
#   'IrW_pv',
#   'IrY_sv',
#   'IrZn',
#   'IrZr_sv',
#   'K_svLa',
#   'K_svLi_sv',
#   'K_svMg_pv',
#   'K_svMn_pv',
#   'K_svMo_pv',
#   'K_svNa_sv',
#   'K_svNb_sv',
#   'K_svNi_pv',
#   'K_svOs_pv',
#   'K_svP',
#   'K_svPb_d',
#   'K_svPd_pv',
#   'K_svPt',
#   'K_svRe_pv',
#   'K_svRh_pv',
#   'K_svRu_pv',
#   'K_svSb',
#   'K_svSc_sv',
#   'K_svSe',
#   'K_svSi',
#   'K_svSn',
#   'K_svSr_sv',
#   'K_svTa_pv',
#   'K_svTc_pv',
#   'K_svTe',
#   'K_svTi_sv',
#   'K_svTl_d',
#   'K_svV_sv',
#   'K_svW_pv',
#   ...],
#  'aflowlib_entries_number': 1528,
#  'auid': 'aflow:LIB2_RAW',
#  'aurl': 'aflowlib.duke.edu:/AFLOWDATA/LIB2_RAW',
#  'keywords': 'aurl,auid,aflowlib_entries_number,aflowlib_entries,keywords,aapi'}
